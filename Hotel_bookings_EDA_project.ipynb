# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshikaPrajapati/PROJECT/blob/main/Hotel_bookings_EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - EDA Capstone Project For Hotel Booking analysis

# %% [markdown]
# ##### **Project Type**    - EDA(Exploratory Data Analysis)
# ##### **Contribution**    - Individual
# ## Name - Anshika Prajapati

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# *   Exploratory Data Analysis(EDA) is an approach to analyze the Data using visual Techniques. It is used to discover trends, patterns or check assumptions with the help of Graphical Representations.
# *In This Project, I am going to begin to Explore the Dataset in which Hotel Booking comprises between two types of hotels For Example, City Hotels and Resort Hotels.
# *In this Dataset we have 119390 Rows, 32 Columns.
# *In this Dataset have 31994 duplicate values and four columns have missing values
# *In this Dataset have Float(4),int(16),object(12)dtype
# *In this Project I have Divided Data manipulation workflow into three different categories (1) Data Collection, (2)Data Cleaning, (3)Data Manipulation and EDA(EXPLORATORY DATA ANALYSIS).
# *Moving Further used Various basic function and attributes like data collectios first step to find various columns which is done by using various method like Head(), Tail(), info(), describe(), some other method used for data collection.
# *Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset. when combining multiple data sources, there are many opportunities for data to be duplicated or mislabeled . If data is correct, outcomes and algorithms are ynreliable, even though they may look correct.
# * The Data type of Reservation_status_date, column was object so it was changed to data type from to better use.
# * Before Visuilizing any type of data need to do data wrangling so, for that so we have checked the null value of all the columns, so after completing the data wrangling then moved to the data visualisation part.
# * Then have to started the data visulizationin a structured way while the following 'UBM' rule.
# * 'U'-Univariate Analysis.
# *  'B'-Bivariate Analysis.
# * 'M'-Multivariate Analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/AnshikaPrajapati/EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you wondered when the best time of years to book a hotel room is?or the optimal length of stay in order to get the best daily rate? what if you wanted to predict whether or not a hotel likely to receive a disproportionately high number of special requests? this hotel Booking dataset can help you explore those question? this dataset contains booking insormation for a city hotel and resort hotel and includes information such as when the booking was made, length os stay and number of adults, children and babies and the number of availabel parking spaces, among other things. all personally identifying information has been removed from the data here, it is given a hotel booking dataset. this dataset contain booking information for a city hotel and resort hotel.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import seaborn as sns 
import ast

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
hotel_df = pd.read_csv("/content/drive/MyDrive/DATA/HotelBookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(hotel_df[hotel_df.duplicated()])
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(hotel_df.isnull().sum().sort_values(ascending = False))
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(10,10))
sns.heatmap(hotel_df.isnull(), cbar = False, yticklabels = False, cmap='viridis')
plt.xlabel("Name of columns", fontsize = 15)
plt.title("places of missing values in column", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'places of missing values in column')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * This Dataset contain 119390 rows and 32 columns
# * All the columns are divided into three datatype : float64(4), int64(16), object(12)
# *  This dataset have Duplicate as well as null values. there are total 31994 duplicate values.
# * The maximum number of missing values from 'company followed by'agent''country'and 'children' maximum number of missing values from company are '112593'.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for elem in hotel_df.columns.tolist():
  print("No. of unique values in", elem, "is", hotel_df[elem].nunique())
# Out:
# No. of unique values in hotel is 2
# No. of unique values in is_canceled is 2
# No. of unique values in lead_time is 479
# No. of unique values in arrival_date_year is 3
# No. of unique values in arrival_date_month is 12
# No. of unique values in arrival_date_week_number is 53
# No. of unique values in arrival_date_day_of_month is 31
# No. of unique values in stays_in_weekend_nights is 17
# No. of unique values in stays_in_week_nights is 35
# No. of unique values in adults is 14
# No. of unique values in children is 5
# No. of unique values in babies is 5
# No. of unique values in meal is 5
# No. of unique values in country is 177
# No. of unique values in market_segment is 8
# No. of unique values in distribution_channel is 5
# No. of unique values in is_repeated_guest is 2
# No. of unique values in previous_cancellations is 15
# No. of unique values in previous_bookings_not_canceled is 73
# No. of unique values in reserved_room_type is 10
# ...

# %%
# Creating a copy of dataframe

df1 = hotel_df.copy()

# %%
# checking the values of categorical columns by one by one
# checking unique value in Hotel column
df1['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df1['is_canceled'].unique()
# Out:
# array([0, 1])

# %%
df1['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
df1['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
df1['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
df1['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
df1['children'].unique()    # This column has 0 as well as null values
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df1.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# company               112593
# agent                  16340
# country                  488
# children                   4
# reserved_room_type         0
# assigned_room_type         0
# dtype: int64

# %%
df1[['company','agent','children']] = df1[['company','agent','children']].fillna(0)
df1[['country']] = df1[['country']].fillna('other')

# %%
# checking all null values is removed
df1.isnull().sum().sort_values(ascending = False)[:6]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# adr                            0
# dtype: int64

# %%
# checking the duplicate values in datasets
len(df1[df1.duplicated()])
# Out:
# 31994

# %%
# Dropping the duplicates Rows
df1 = df1.drop_duplicates()

# %%
# checking the shape of dataset whose combining values of adults,babies and childrens columns is 0
df1[df1['adults']+df1['babies']+df1['children'] == 0].shape
# Out:
# (166, 32)

# %%
df1.shape
# Out:
# (87396, 32)

# %%
# Dropping the rows where combining the values of adults, childrens and babies columns is 0 because of no booking was made
df1.drop(df1[df1['adults']+df1['babies']+df1['children'] == 0].index, inplace = True)

# %% [markdown]
# ### **Converting columns to appropriate datatypes.**

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df1[['children', 'company', 'agent']] = df1[['children', 'company', 'agent']].astype('int64')

# %%
# changing datatype of column 'reservation_status_date' to data_type.
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'])
# Out:
# <ipython-input-26-f9a6065da0ea>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'])

# %% [markdown]
# ### **Adding important columns.**

# %%
# Adding total staying days in hotels
df1['total_stay'] = df1['stays_in_weekend_nights']+df1['stays_in_week_nights']

# Adding total people num as column, i.e. total people num = num of adults + children + babies
df1['total_people'] = df1['adults']+df1['children']+df1['babies']

# %%
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# we have done the following manipulation insight found by as follow:-
#
#
# *   we have found there were 4 columns containing Null values: Company, agents, country, and children.
# *   so for company and agents we have filled the missing values with 0
#
# *   as the count of missing values of children is only 4
# *   this dataset also containing duplicate values so the duplicate values is dropped.
#
# *   we found the combining values of children, adults and babies was 0 so we dropped them , after all combining the values of children, adults,and babies of rows and columns was dropped
# *   the data type of reservation_status_date was object changed into datetype format for betrrer use
# *   that is two columns were added first is 'total_people and other is total_stay'.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
df1['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct = '%1.1f%%', shadow = True, figsize=(10,8), fontsize = 21)
plt.title('pie chart for most preferred hotel', fontsize=15)
# Out:
# Text(0.5, 1.0, 'pie chart for most preferred hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Pie-Chart is expressed the whole relationship of the data. it is very easy to explain the percentage comparison through area covered in a circle with different colors. wherever percentage comparison comes into action so frquently used pie-chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above Chart, we get to know that city hotel is modt preferred hotel by guests. thus city hotel has maximum booking 61.1% guests preffered city hotel while 39.9 guests preffered Resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# city hotel doing very well so they are providing more services for attracting more guest to increase his revenue, so they are doing really well but in case of resort hotel guest have shown less interest than city hotel so resort hotel need  to find our better solution for attracting more guest and find what city hotel has done to attract guests, so there is very high scope of growth of resort if they upgrade their service and adopt there better way

# %% [markdown]
# #### Chart - 2 :-

# %%
# Chart - 2 visualization code
grp_by_hotel = df1.groupby('hotel')

# %%
highest_adr = grp_by_hotel['adr'].mean().reset_index()

plt.figure(figsize = (5,8))

plt.xlabel('hotel type', fontsize = 15)
plt.ylabel('ADR', fontsize=15)
plt.title('average ADR of each hotel type', fontsize = 15)

sns.barplot(x = highest_adr['hotel'], y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'average ADR of each hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   Because the bar chart is how the frequency counts of values for the different levels of a categorial nominal variable .
# *   to showing the average of each hotel type in a clear or feasible way. so we have used bar chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Resort Hotel has highest Adr. That means city hotel is generating more revenue than City Hotel.
# *   so the Resort Hotel has can more advertising to get more revenue. Thus the Resort Hotel are already enjoying high adr but bit more of positive efforts towards more definitely add alot to their growth and overall revenue.

# %% [markdown]
# #### Chart - 3:- Relationship between Adr and Total stay

# %%
# Chart - 3 visualization 
adr_vs_stay = df1.groupby(['total_stay', 'adr', 'hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns = {'is_canceled' : 'number of stays'})
adr_vs_stay = adr_vs_stay [: 18000]
adr_vs_stay
# Out:
#        total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               1    0.00    City Hotel
# 3               1    0.00  Resort Hotel
# 4               1    4.00  Resort Hotel
# ...           ...     ...           ...
# 13670          46    0.00  Resort Hotel
# 13671          56   25.50  Resort Hotel
# 13672          56   28.79  Resort Hotel
# 13673          60  110.50  Resort Hotel
# 13674          69  110.00  Resort Hotel
#
# [13675 rows x 3 columns]

# %%
# plotting the graph in line chart
plt.figure(figsize = (8,8))
sns.lineplot(x = 'total_stay', y= 'adr', data= adr_vs_stay)
plt.xlabel('total_stay',fontsize = 15)
plt.ylabel('adr', fontsize=15)
plt.title('Relationship between adr and total stay', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# From this chart we have found that as the total stal increases the adr also increases so, adr is directly proportional to the total_stay.

# %% [markdown]
# ##### 2. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   The hotel should focus on increasing thier Adr and more advertisement and better facilities and good offers will let the guests to stay more that will directly result in increasing edr.so, hotels should offer more attractive offers and facilities so that total stay can be increased will directly multiply their edr and ultimately will increases

# %% [markdown]
# #### Chart - 4 :- Percentage of Repeated Guests

# %%
# Chart - 4 visualization code
df1['is_repeated_guest'].value_counts().plot.pie(explode=(0.05, 0.05),autopct='%1.1f%%', shadow= True, figsize = (12,8), fontsize = 20)
plt.title("percentage (%) of repeated guest", fontsize =15)
# Out:
# Text(0.5, 1.0, 'percentage (%) of repeated guest')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is usedto represent the proportional data or relative data in a single chart. the concept of pie slices is used to show the percentage of a particular data from a whole pie.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Repeated guest are very less which is only 3.3% while 96.7% guest are not returning to the same hotel So, it is amtter of deep thinking and taking proper step to increases a repeated guest numbers. in order to retained the guests management should take feedback from the guests and try to impress with his services.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it's True the Repeated guests are very less, so if the hotel will work on his side also to increase his repeated guest will ultimately they will boost his revenue so, they need to take right step should be taken feedback from then finding problems and solving customers problems within a time and offering him best services and offers to the customers.

# %% [markdown]
# #### Chart - 5 :- Percentage Distribution of required_car_parking_spaces

# %%
# Chart - 5 visualization code
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%', shadow=False, figsize=(12,8), fontsize=20)
labels = df1['required_car_parking_spaces'].value_counts().index
plt.title('%distribution of required car parking spaces', fontsize = 15)
plt.legend(bbox_to_anchor=(0.05, 1), loc= 'upper left', labels = labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we have used pie chart because it gives the output in more understanding manner as here we can clearly see the different two colors reflecting the demand of car parking spaces by guests. so its very useful chart to get proper insight as we can use other chart also but we have fount it more relevent here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that 89.4% guests did not required the parking spaces. only 10.5% guests required only parking spaces

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes that insight definetely help the hotel to provide better services . it can be said that hotels need to work less on car parking spaces as only 1 car parking spaces were required by 10.5% guest. so it is better to have a limited car parking spaces and use that spaces for other important purpose rather than just leeting go unused. so it is better to focus on other areas to increase quality of hotel rather than focusing mainly on car parking area only. the demand of car parking area is less. this might be the reason as too many guests prefer to use public vehicles to travel.

# %% [markdown]
# #### Chart - 6:- Pie Chart for mostly used for distribution channels and relationship of distribution channel and Adr

# %%
distribution_channel_df= df1.groupby(['distribution_channel', 'hotel'])['adr'].mean().reset_index()
plt.figure(figsize = (12,8))
sns.barplot(x='distribution_channel', y='adr', data= distribution_channel_df, hue='hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart shows the frequency counts of values for the different levels of a categorical or nominal variable.

# %% [markdown]
# #### Chart - 7:- Meal Type Distribution

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,7))
sns.countplot(x=df1['meal'])
plt.xlabel('meal type', fontsize= 15)
plt.ylabel('count', fontsize=15)
plt.title('preferred meal type', fontsize=15)
# Out:
# Text(0.5, 1.0, 'preferred meal type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we have used this count plot because it shows the count of catogorical bin using bars. bar plots look similar to count plots. but instead of using count plots of observation in each category. they shows the means of a quantative variable among observation in each category. so we have used this count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# inside the chart we found the meals which is most preferred by the guests is BB(Bed and Breakfast) while HB(Half Board) and SC(self catering) are equally preferred. type of meals are as follow:
# BB-(Bed and Breakfast), HB-(Half Board), FB-(Full-Board), SC-(Self-Catering)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So, the insights has positive impact of hotels needs to focus more on the BB meal type so that the majority of customers are satisfied while others types of ,eals should be given equal importance with proper management of food services so as the guests we need to give best offer of services to customers.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
bookings_by_months_df = df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':'counts'})
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August','September', 'October', 'November', 'DEcember']
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'], categories=months, ordered= True)
bookings_by_months_df= bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month  counts
# 4             January    2425
# 3            February    2988
# 7               March    3497
# 0               April    3735
# 8                 May    3284
# 6                June    2759
# 5                July    4564
# 1              August    5583
# 11          September    3520
# 10            October    3205
# 9            November    2237
# 2                 NaN    2379

# %%
plt.figure(figsize = (10,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'], y=bookings_by_months_df['counts'])
plt.title('numbers of booking across each month', fontsize =15)
plt.xlabel('month', fontsize = 15)
plt.ylabel('numbers of bookings', fontsize = 15)
# Out:
# Text(0, 0.5, 'numbers of bookings')

# %%
stay = df1.groupby(['total_stay', 'hotel']).agg('count').reset_index()
stay = stay.iloc[:, :3]
stay = stay.rename(columns={'is_canceled': 'Number of stays'})

# %%
plt.figure(figsize= (12,9))
sns.barplot(x='total_stay', y = 'Number of stays', hue='hotel', data=stay)
plt.title('optimal stay lenth in each hotel types', fontsize=15)
plt.ylabel('count of stay', fontsize = 15)
plt.xlabel('total_stay(days)', fontsize =15)
# Out:
# Text(0.5, 0, 'total_stay(days)')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9 :- Plotting Histogram

# %%
# Chart - 9 visualization code              
df1.hist(figsize= (23,18))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to understand the data in clear way with proper insights we have used histogram here. this histogram is a popular graphing tool. it is used to summarize descrete or continous data that are measured on a inteval scale. it is often used to illustrate the major features of the distribution of the data in a convenient form. it is also useful when dealing with large data sets (greater than 100 observation). it can help detect any whole dataset whether it is symmetric or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# some insights are found from the chart are as follows:
#
#
# *   we can see maximum guest come in the year of 2016
# *   maximum week number is 30.
# *   maximum arrival happen in the last of the month.
# *   maximum guest come with no children.
#
#
#
#
#
#
#
#
#
# ---

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Histogram cannot define bussiness impact. it is just to see the distribution of the column data over the dataset.

# %% [markdown]
# #### Chart - 10 :- Year and Hotel wise confirmed booking and cancellation Distribution

# %%
# Chart - 10 visualization code
plt.figure (figsize = (12,5))
sns.countplot(x='hotel', hue='is_canceled', palette='Set2', data= df1)
plt.legend(['confirmed', 'canceled'])
plt.title('hotel wise confirmation and cancellation of the bookings', fontsize=18)
plt.ylabel('count of confirmaation and cancellation', fontsize= 15)
plt.xlabel('hotel', fontsize= 15)
# Out:
# Text(0.5, 0, 'hotel')

# %%
data_not_canceled = df1[df1['is_canceled']==0]
sns.set_style(style = 'darkgrid')
plt.figure(figsize = (12,5))
sns.countplot(x='arrival_date_year', hue= 'hotel', palette= 'tab10', data= data_not_canceled)
plt.legend(['Resort Hotel', 'City Hotel'])
plt.title("yearwise booking of hotels", fontsize= 16)
plt.ylabel('Number of Bookings', fontsize = 15)
plt.xlabel('year', fontsize=15)
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we have out the count plot to get proper insight on hotel wise cancellation of bookings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above graph it is clear that city hotel is having greater number of bookings as compared to Resort Hotel.
# It can be summarized that the year 2016 both the hotel saw massive increases their Booking and by far the year 2016 is the year of highest booking of both hotel.

# %% [markdown]
# #### Chart - 11 :- ADR across different month

# %%
# Chart - 11 visualization code
bookings_by_months_df= df1.groupby(['arrival_date_month', 'hotel'])['adr'].mean().reset_index()
months= ['january', 'February', 'March', 'April', 'May', 'June','July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'], categories=months, ordered=True)
bookings_by_months_df = bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 6            February    City Hotel   79.891008
# 7            February  Resort Hotel   54.102809
# 14              March  Resort Hotel   57.590889
# 13              March    City Hotel  101.573817
# 0               April    City Hotel  105.930650
# 1               April  Resort Hotel   79.283805
# 16                May  Resort Hotel   80.551101
# 15                May    City Hotel  114.948626
# 12               June  Resort Hotel  112.380859
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel   66.797410
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel   84.870349
# 21          September    City Hotel   99.266299
# 22          September  Resort Hotel  100.892331
# 19            October    City Hotel   85.714096
# 20            October  Resort Hotel   63.723065
# 17           November    City Hotel   68.873548
# 18           November  Resort Hotel   48.871043
# ...

# %%
plt.figure(figsize = (10,4))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'], y= bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])
plt.title ('ADR across each month', fontsize= 15)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('ADR', fontsize = 15)
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we have pick line chart to get the clear ADR by the City and Resort hotels Across each month, Line chart is very useful because it helps to shows small shifts that may be getting hard to spot in other graphs. it help show trend for different periods, they are easy to understand to compare data, more than one line can be plotted the same axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   For Resort hotel, ADR is high in the months of june, july, august as compared to city hotels. the reason may be that customers/people want to spend their summer vacation in resort hotels.
# *  best time for guest to visit resort or city hotel is january, february, march, april, october, november, and december as the average daily rate of this months is very low. so it would be feasible and sustainable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# So, thr higher ADR, the higher will be revenue so it's a good sign. hotels should work more to enhance their adr by offering good schemes to attract customer in winter vacation also and no other holidays.

# %% [markdown]
# #### Chart - 12:- Room type preference and customer type

# %%
# Chart - 12 visualization code
plt.figure(figsize= (10,8))
sns.countplot(x= df1['assigned_room_type'], order= df1['assigned_room_type'].value_counts().index)
plt.title('Most preffered room type', fontsize = 15)
plt.xlabel('Room Type', fontsize=15)
plt.ylabel('Count of Room Type', fontsize = 15)
# Out:
# Text(0, 0.5, 'Count of Room Type')

# %%
plt.figure(figsize= (12,5))
sns.countplot(x='arrival_date_month', hue = 'customer_type', data= df1)
plt.ylabel('Months', fontsize=15)
plt.xlabel('Number of Customers', fontsize= 15)
# Out:
# Text(0.5, 0, 'Number of Customers')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For, 1st Visualization, we have picked the bar chart to display result for this set of code, here I have used bar graph to show the distributed by volume(count of room), which type room alloted here summarize the large set of data in a simple form.
# From 2nd visualization, chart involve count plot it help the number of insights and visualization to easy to following chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the first count plot we got data most prefer Type A so majurity of guest have shown interest to this Room.
# From the above graph it can be measured that the transcient type of customers visits the most comes in the category of least visitors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes from the graph we got positive impact because 'A', 'D', 'E' most prefered due to better service offer by in room type.

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize = (16,11))
sns.heatmap(df1.corr(), annot= True)
plt.title('co-relation of the columns', fontsize = 15)
# Out:
# <ipython-input-72-a10c30826c24>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), annot= True)
# Text(0.5, 1.0, 'co-relation of the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A co-relation matrix is table showing corelation co-efficient between variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 1.  is_canceled and total stay are negative corelated.this customer unlikely to cancel their booking.
# 2.  lead_time and total_stay is positively corelated.
# 3.  adult, childrens and babies are correlated with each other . this inducates more the people more will be adr
# 4.  is_repeated guests and previous booking not_cancel have strong corelation.
# 5.  so there are some more powerful insight found from the chart of corelation heatmap.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Bussiness Objective attained as follows:
#
#
# *   To attain high growth and more success, hotel bussiness need to flourish and for that few things which we need to consider high revenue generation, customers satisfaction and employee retention.
# *   we are able to achieve the same by showing the client which are the month is high revenue generation by using various charts and graphs distribution.
# *   Enhancing the revenue adopted by bar chart distribution of which type room are most prefered and resevered and which are the months suitable for visitors
# *   we also have founded the various prefernce in different categoris like meal type, optimal stay lenth, facilities require by customers like  car parking spaces,etc. so this all insight need to better planning for growth and revenue.
# *   so preparing well by understanding these all the outcomes, the client can be well prepared in advance so that minimum greivances would be faced by clients in long run and would help in further enhancement of their hospitality and service.
# *   ask feedback often from the guests visiting the hotels so the quality can be upgraded to the next level to increase more guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  City hotel are most preffered hotel by the guest, so we can say that city hotel is busiest hotel in comparison of the resort hotel.
# *   the percentage of repeated guest is very low. only 3.9% people revisited the hotels and rest 96.1% were new guests. so the retention rate is much low
# *   Among the different type of meals, BB(Bed and Breakfast) is the most preferred meals by the guests. so the guests is loved to opt. this type meals.
# *   Direct and TA/TO have equally contribution in adr in both types of hotel, city hotels and resort hotels.
# *  Optimal stay length in both hotels is less than 7 days. Usually people stay for a week after 7 days optimal stay lenth is declined drastically.
# *   Most numbers of bookings have taken place in moth of july and august.
# *   1/4th of the total booking is cancelled. Approx 27.5% have got cancelled out of all bookings.
# *   Majority of guests have shown interest in the room type'A'. Room type 'A' is the most prefferd Room type.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
